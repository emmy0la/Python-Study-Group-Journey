# %% [raw]
# Exercise 1 – Printing Text

# %%
print("Hello, World!")
print("My name is Emmanuel Olawumi")
print("I am learning Python.")
print("Programming is exciting!")
# Out:
# Hello, World!
# My name is Emmanuel Olawumi
# I am learning Python.
# Programming is exciting!

# %% [raw]
# Exercise 2 – Multiple Print Statements

# %%
print("My favorite food is Amala.")
print("My favorite movie is The Pursuit of Happyness.")
print("My favorite sport is Football.")
print("My favorite color is Blue.")
# Out:
# My favorite food is Amala.
# My favorite movie is The Pursuit of Happyness.
# My favorite sport is Football.
# My favorite color is Blue.

# %% [raw]
# Exercise 3 – Python Calculator

# %%
print(15 + 5)
print(30 - 12)
print(9 * 8)
print(72 / 9)
print(18 % 5)
print(10 // 3)
print(5 ** 2)
# Out:
# 20
# 18
# 72
# 8.0
# 3
# 3
# 25

# %% [raw]
# Exercise 4 – Understanding Comments

# %%
# Display the programming language
print("Python")

# Display the subject being studied
print("Programming")

# Display the current lesson
print("Lesson One")
# Out:
# Python
# Programming
# Lesson One

# %% [raw]
# Exercise 5 – Mini Challenge

# %%
# Exercise 5 – Mini Challenge

# Print my name
print("Emmanuel Olawumi")

# Print my dream career
print("Data Scientist")

# Print my country
print("Nigeria")

# Calculate the sum of two numbers
print(25 + 75)

# Perform floor division
print(40 // 6)

# Calculate 8 raised to the power of 2
print(8 ** 2)
# Out:
# Emmanuel Olawumi
# Data Scientist
# Nigeria
# 100
# 6
# 64
